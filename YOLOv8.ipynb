# %%
from ultralytics import YOLO

# %%
model = YOLO("data/weights/YOLOV8Nbest.pt")


#yolo task=detect mode=predict model='data/weights/YOLOV8best.pt' source='2.mp4' show=True

# %%
results = model.predict("data/dataset/train/G1196__147__0-57__0-59__fix_anonymized__frame-1_png.rf.f9f0469f2175ade628e02d29134d6385.jpg")
# Out:
# image 1/1 C:\Users\medkh\OneDrive\Desktop\projects\children_moitoring\data\dataset\train\G1196__147__0-57__0-59__fix_anonymized__frame-1_png.rf.f9f0469f2175ade628e02d29134d6385.jpg: 480x480 3 kids, 2 persons, 113.7ms
# Speed: 4.0ms preprocess, 113.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)

# %%
# Visualize the results on the frame
import matplotlib.pyplot as plt

annotated_frame = results[0].plot()
plt.imshow(annotated_frame)
