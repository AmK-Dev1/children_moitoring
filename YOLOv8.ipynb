# %%
from ultralytics import YOLO

# %%
model = YOLO("data/weights/YOLOV8best.pt")


#yolo task=detect mode=predict model='data/weights/YOLOV8best.pt' source='2.mp4' show=True

# %%
results = model.predict("data/images/test5.PNG")
# Out:
# image 1/1 C:\Users\medkh\OneDrive\Desktop\projects\children_moitoring\data\images\test5.PNG: 384x640 (no detections), 340.4ms
# Speed: 8.0ms preprocess, 340.4ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Visualize the results on the frame
import cv2
import matplotlib.pyplot as plt

annotated_frame = results[0].plot()
plt.imshow(annotated_frame)
# Out:
# Le Kernel s’est bloqué lors de l’exécution du code dans la cellule active ou une cellule précédente. Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec. Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations. Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
